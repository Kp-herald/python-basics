# %%
tuple()
print(tuple)
# Out:
# <class 'tuple'>

# %%
tpl=[(1,23,4,5)]
print(tpl)
# Out:
# [(1, 23, 4, 5)]

# %%
lst=['we','are','one',3,'in',1]
print(lst)
# Out:
# ['we', 'are', 'one', 3, 'in', 1]

# %%
tpl=(1,3,5,6)
print(tpl)
# Out:
# (1, 3, 5, 6)

# %%
#tuples operation
tpl2=('jesus','christ','is','the','one')
print(tpl2)
# Out:
# ('jesus', 'christ', 'is', 'the', 'one')

# %%
#concatination
tpl + tpl2
# Out:
# (1, 3, 5, 6, 'jesus', 'christ', 'is', 'the', 'one')

# %%
tpl *2
# Out:
# (1, 3, 5, 6, 1, 3, 5, 6)

# %%
tpl2 *3
# Out:
# ('jesus',
#  'christ',
#  'is',
#  'the',
#  'one',
#  'jesus',
#  'christ',
#  'is',
#  'the',
#  'one',
#  'jesus',
#  'christ',
#  'is',
#  'the',
#  'one')

# %%
#list
lst
# Out:
# ['we', 'are', 'one', 3, 'in', 1]

# %%
lst[2]=1;lst[5]='one'
print (lst)
# Out:
# ['we', 'are', 1, 3, 'in', 'one']

# %%
tpl2
# Out:
# ('jesus', 'christ', 'is', 'the', 'one')

# %%
tpl2[4]=1 # it is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tpl2[4]=1 # it is immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
lst.append('one')
print(lst)
# Out:
# ['we', 'are', 1, 3, 'in', 'one', 'one']

# %%
lst.insert(4,'in')
print(lst)
# Out:
# ['we', 'are', 1, 3, 'in', 'one']

# %%
num=1,2,5,3,4,5,7,5,7,3,4
print(num)
# Out:
# (1, 2, 5, 3, 4, 5, 7, 5, 7, 3, 4)

# %%
print(num.count(5))
print(num.index(7))
# Out:
# 3
# 6

# %%
#packing and unpacking
#packing
num=1,"herald",3.4,True
print(num)
# Out:
# (1, 'herald', 3.4, True)

# %%
#unpacking
a,b,c,d=num
print(a)
print(d)
print(b)
print(c)
# Out:
# 1
# True
# herald
# 3.4

# %%
*first,middle,last=num
print(first)
print(middle)
print(last)
# Out:
# [1, 'herald']
# 3.4
# True

# %%
## nested list 
lst=[[1,2,3,5],[4,6,8,9],["herald",3.91,7,"love is jesus"]]
print(lst[1][:])
# Out:
# [4, 6, 8, 9]

# %%
#nested tuple
tpl=(('a','n',"v"),(1,2,3,4),(1,"jesus",3.14))
print(tpl[0][:3])
# Out:
# ('a', 'n', 'v')

# %%
for tp in tpl:
    for i in tp:
        print(i,end=" ")
    print()
# Out:
# a n v
# 1 2 3 4
# 1 jesus 3.14
