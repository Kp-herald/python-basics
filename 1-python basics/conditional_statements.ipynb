# %%
# if statement
age=10
if age>18:
    print("you are an adult")
else:
    print("you are a child")
# Out:
# you are a child

# %%
# elif statement
age=22
if age<13:
    print("you are a child")
elif age<18:
    print("you are a teenager")
else:
    print("you are not a teenager anymore get a job")
# Out:
# you are not a teenager anymore get a job

# %%
# nested if
num=int(input("enter a number"))
if num>0:
    print("number is positive")
    if num%2==0:
        print("the number is even")
    else:
        print("the number is odd")
elif num==0:
    print("number is zero")
else:
    print("number is negative")
# Out:
# number is negative

# %%
# find if a year is leap year or not with nested if

year=int(input("enter a year"))

if year%4==0:
    if(year%100!=0 or year%400==0):
            print("it is a leap year")
    else:
            print("not a leap year")
else:
    print("it is not a leap year")
# Out:
# it is not a leap year

# %%
# find if a year is leap year or not with nested if

year=int(input("enter a year"))

if year%4==0:
    if year%100==0:
        if year%400==0:
            print("it is a leap year")
    else:
            print("is a leap year")
else:
    print("it is not a leap year")
# Out:
# it is not a leap year

# %%
# simple calculator
num1=int(input("enter number 1:"))
num2=int(input("enter number 2:"))
op=input("enter a operator (ex: +, -, *, /")

if op == '+' :
    print(f"{num1} + {num2} = {num1 + num2}")
elif op == "-":
    print(f"{num1} - {num2} = {num1 - num2}")
elif op == "*":
    print(f"{num1} * {num2} = {num1 * num2}")
elif op == "/":
    if num2!=0:
        print(f"{num1} / {num2} = {num1 / num2}")
    else:
        print("error, number can't divisible by '0'")
else:
    print("invalid operator")
# Out:
# invalid operator

# %%
# bus ticket 
age=int(input("enter your age:"))
is_student=input("Are you a student: Yes or No").lower()
if age<5:
    price="free"
elif age<12:
    price="10$"
elif age<=17:
    if is_student =="yes":
        price="15$"
    else:
        price="20$"
elif age<=60:
    if is_student=="yes":
        price="25$"
    else:
        price="35$"
else:
    price="30$"

print(f"your ticket price is {price}")
# Out:
# your ticket price is 20$
