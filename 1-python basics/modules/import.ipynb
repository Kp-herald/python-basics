# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt,pi
print(sqrt(625))
print(pi)
# Out:
# 25.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from package import maths
maths.add(7,19)
# Out:
# 26

# %%
from package.maths import *
from package.subpack.multi import *
print(add(1,3))
print(sub(3,2))
print(multiply(10,5))
# Out:
# 4
# 1
# 50
