# %%
age=22
name="herald"
Faith="in jesus christ alone"
is_believer=True
print("age:",age)
print("name:",name)
print("faith:",Faith)
# Out:
# age: 22
# name: herald
# faith: in jesus christ alone

# %%
##valid variables
##invalid variables

##valid
name_is="herald"
_age=22
faith7="in lord god"
print(name)
print(age)
print(faith7)
print(Faith)
# Out:
# herald
# 22
# in lord god
# in jesus christ alone

# %%
# invalid
# 2day="monday"
# @mail="kpherald7"
# name-="pramod"
# print(name-)
# Out:
#   Cell In[8], line 5
#     print(name-)
#                ^
# SyntaxError: invalid syntax

# %%
#type checking and conversion
age=22 #int
name="herald" #string
height=5.8 #float
is_believer=True #boolean

print(type(height))
# Out:
# <class 'float'>

# %%
#type conversion
age="22"
print(int(age))
print(type(int(age))\
)
# Out:
# 22
# <class 'int'>

# %%
#for float
print(type(height))
print(type(int(height)))
print(float(int(height)))
print(int(float(int(height))))
# Out:
# <class 'float'>
# <class 'int'>
# 5.0
# 5

# %%
#for string
statement="herald loves jesus"
print(type(statement))
# int(statement) it will be value error since it is a complete  string
# Out:
# <class 'str'>

# %%
#dynamic typing
#python allows change of type 
val=22
print(val,type(val))
val="herald"
print(val,type(val))
val=33.3
print(val,type(val))
# Out:
# 22 <class 'int'>
# herald <class 'str'>
# 33.3 <class 'float'>

# %%
# input format
age=int(input("what is your age"))
print(age,type(age))
# Out:
# 22 <class 'int'>

# %%
## simple calculator
num1=int(input("enter number 1"))
num2=int(input("enter number 2"))

sum=num1+num2
subtraction=num1-num2
multiplication=num1*num2
division=num1/num2
quotiant=num1%num2

print("addition of both numbers :",sum)
print("subtraction of both numbers:",subtraction)
print("multiplication of both numbers :",multiplication)
print("division of both numbers",division)
print("quotiant of the number :",quotiant)
# Out:
# addition of both numbers : 22
# subtraction of both numbers: 18
# multiplication of both numbers : 40
# division of both numbers 10.0
# quotiant of the number : 0
