# %%
print("jesus is the way")
# Out:
# jesus is the way

# %%
##single comment where we can write a line or a piece of code which is in normal english or a sentence

# %%
## indentation
age=22
if age<25:
    print(age+2)
print(age+1)
# Out:
# 24
# 23

# %%
##single line comment
print("all praise to jesus")
# Out:
# all praise to jesus

# %%
## line continuation
a=1+2+3+7+5+3+4\
+3+4+5+4
print(a)
# Out:
# 41

# %%
## mutli statement in a single line
a=7;b=33;c=a+b;d=a-b
print(c)
print(d)
# Out:
# 40
# -26

# %%
##understanding the semantics
age=3
name="samuel"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
name="jesus"
type(name)
# Out:
# str

# %%
## type interference
age=22
print(type(age))
age="twenty two"
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=12
age="twelve"
print(type(age))
# Out:
# <class 'str'>

# %%
##indentation in programm
if True:
    print("jesus is the way")
    if False:
        print("nothing is possible")
    print("god can make it happen")
print("trust in the lord with all your heart")
# Out:
# jesus is the way
# god can make it happen
# trust in the lord with all your heart
