# %%
## data types
#int #string #bool 

age=22
print(type(age))
# Out:
# <class 'int'>

# %%
name="herald"
type(name)
# Out:
# str

# %%
#float
height=5.10
type(height)
# Out:
# float

# %%
a=10
b=10
a==b
# Out:
# True

# %%
a="jesus"
b="christ"
a==b
# Out:
# False

# %%
a="jesus"
b="jesus"
a==b
# Out:
# True

# %%
bool=True
type(bool)
# Out:
# bool

# %%
#convatination

#var="JESUS LOVES YOU"+5
var="JESUS LOVES YOU "+str(5)
print(var)
# Out:
# JESUS LOVES YOU 5
