# %% [markdown]
# # Module: Pandas Assignments
# ## Lesson: Pandas
# ### Assignment 1: DataFrame Creation and Indexing
#
# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
# 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.
#
# ### Assignment 2: DataFrame Operations
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.
#
# ### Assignment 3: Data Cleaning
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.
#
# ### Assignment 4: Data Aggregation
#
# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.
#
# ### Assignment 5: Merging DataFrames
#
# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.
#
# ### Assignment 6: Time Series Analysis
#
# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.
#
# ### Assignment 7: MultiIndex DataFrame
#
# 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.
# 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.
#
# ### Assignment 8: Pivot Tables
#
# 1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.
# 2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.
#
# ### Assignment 9: Applying Functions
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
# 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.
#
# ### Assignment 10: Working with Text Data
#
# 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
# 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

# %%
## assignment 1
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randint(1,25,(6,4)),columns=["A","B","C","D"])
print(f"original table:\n{df}")

ch=df.set_index("A")
print(ch)
# Out:
# original table:
#     A   B   C   D
# 0   2  12   6  11
# 1  17  23  15   2
# 2   1   6  13   1
# 3  21  21  11  16
# 4  18  14   2  22
# 5  11   5   7  11
#      B   C   D
# A
# 2   12   6  11
# 17  23  15   2
# 1    6  13   1
# 21  21  11  16
# 18  14   2  22
# 11   5   7  11

# %%
import numpy as np 
import pandas as pd

df=pd.DataFrame(np.random.randint(1,71,(3,3)),columns=["A","B","C"],index=["X","Y","Z"])
print(f"Original:\n{df}")

ele=df.loc["Y","B"]
print(f"element at Y index and B column:\n{ele}")
# Out:
# Original:
#     A   B   C
# X  50   5  42
# Y  70   6  41
# Z  20  40  47
# element at Y index and B column:
# 6

# %%
# assignment 2
import numpy as np 
import pandas as pd
df=pd.DataFrame(np.random.randint(1,20,(5,3)))
print(f"original:\n{df}")

df[3]=df[0]*df[1]
print(df)
# Out:
# original:
#     0   1   2
# 0  15   3   1
# 1  15  14   6
# 2   4  18   7
# 3   8  18  10
# 4   7  14   7
#     0   1   2    3
# 0  15   3   1   45
# 1  15  14   6  210
# 2   4  18   7   72
# 3   8  18  10  144
# 4   7  14   7   98

# %%
df=pd.DataFrame(np.random.randint(1,20,(4,3)))
print(f"original:\n{df}")
rsum=df.sum(axis=1)
csum=df.sum(axis=0)
print(f"row wise sum:\n{rsum}")
print(f"column wise sum:\n{csum}")
# Out:
# original:
#     0   1   2
# 0  17   5  15
# 1  19  16  11
# 2   3   7  16
# 3   7  12  11
# row wise sum:
# 0    37
# 1    46
# 2    26
# 3    30
# dtype: int64
# column wise sum:
# 0    46
# 1    40
# 2    53
# dtype: int64

# %%
# assignment 3
df=pd.DataFrame(np.random.randint(0,15,(5,3)),columns=["A",'B','C']).replace(0,np.nan)
print(f"original:\n{df}")
re=df.fillna(df.mean())
print(re)
# Out:
# original:
#       A   B   C
# 0   8.0   8  10
# 1   2.0   9   1
# 2   NaN  10  10
# 3  11.0   9   7
# 4   3.0  13  13
#       A   B   C
# 0   8.0   8  10
# 1   2.0   9   1
# 2   6.0  10  10
# 3  11.0   9   7
# 4   3.0  13  13

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.randint(0,24,(6,4)),columns=['A','B','C','D']).replace(0,np.nan)
print(f"original:\n{df}")
d=df.dropna()
print(f"removed null :\n{d}")
# Out:
# original:
#     A     B   C   D
# 0   6   4.0   6  18
# 1  23  13.0  16   2
# 2  12   4.0  17  14
# 3  16   3.0   7  18
# 4  18   NaN   3  12
# 5  12  16.0  21  10
# removed null :
#     A     B   C   D
# 0   6   4.0   6  18
# 1  23  13.0  16   2
# 2  12   4.0  17  14
# 3  16   3.0   7  18
# 5  12  16.0  21  10

# %%
#assignment 4
import pandas as pd
import numpy as np
df=pd.DataFrame()
df["category"]=np.random.choice(["A","B","C"],size=5)
df["value"]=np.random.randint(1,50,size=5)
print(f"original:\n{df}")
df.groupby("category")["value"].agg(['count','sum','mean'])
# Out:
# original:
#   category  value
# 0        A     14
# 1        A     41
# 2        B     30
# 3        C     46
# 4        C     21
#           count  sum  mean
# category
# A             2   55  27.5
# B             1   30  30.0
# C             2   67  33.5

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({"Products":np.random.choice(["prod1","prod2","prod3"],size=10),"Category":np.random.choice(["A",'B','C'],size=10),'Sales':np.random.randint(1,100,size=10)})
print(f"original:\n{df}")
total=df.groupby("Category")["Sales"].sum()
print(total)
# Out:
# original:
#   Products Category  Sales
# 0    prod1        C     63
# 1    prod1        C     77
# 2    prod1        B     30
# 3    prod2        C     49
# 4    prod3        B     57
# 5    prod3        A     50
# 6    prod1        A     13
# 7    prod2        C     91
# 8    prod3        B     33
# 9    prod3        C     95
# Category
# A     63
# B    120
# C    375
# Name: Sales, dtype: int32

# %%
#assignment 5
import pandas as pd
import numpy as np
d1=pd.DataFrame({"key":['A','B','C','D','E'],"values":np.random.randint(1,100,size=5)})
d2=pd.DataFrame({"key":['A','B','C','G','H'],"values":np.random.randint(1,100,size=5)})
print(f"dataframe 1:\n{d1}")
print(f"dataframe 2:\n{d2}")
re=pd.merge(d1,d2,on="key",how="left")
print(re)
# Out:
# dataframe 1:
#   key  values
# 0   A      19
# 1   B      13
# 2   C      61
# 3   D      86
# 4   E      95
# dataframe 2:
#   key  values
# 0   A      39
# 1   B      58
# 2   C       7
# 3   G      86
# 4   H      21
#   key  values_x  values_y
# 0   A        19      39.0
# 1   B        13      58.0
# 2   C        61       7.0
# 3   D        86       NaN
# 4   E        95       NaN

# %%
d1=pd.DataFrame({"A":np.random.randint(1,30,size=3),"B":np.random.randint(1,30,size=3)})
d2=pd.DataFrame({"C":np.random.randint(1,30,size=3),"D":np.random.randint(1,30,size=3)})
print(f"dataframe 1:\n{d1}")
print(f"dataframe 2:\n{d2}")
dfr=pd.concat([d1,d2],ignore_index=True)
dfc=pd.concat([d1,d2],axis=1)
print(f"dataframe row wise:\n{dfr}")
print(f"dataframe column wise:\n{dfc}")
# Out:
# dataframe 1:
#     A   B
# 0  12   9
# 1   5  14
# 2  23  24
# dataframe 2:
#     C   D
# 0  22  16
# 1   2   5
# 2  14   4
# dataframe row wise:
#       A     B     C     D
# 0  12.0   9.0   NaN   NaN
# 1   5.0  14.0   NaN   NaN
# 2  23.0  24.0   NaN   NaN
# 3   NaN   NaN  22.0  16.0
# 4   NaN   NaN   2.0   5.0
# 5   NaN   NaN  14.0   4.0
# dataframe column wise:
#     A   B   C   D
# 0  12   9  22  16
# 1   5  14   2   5
# 2  23  24  14   4

# %%
# assignment 6
import pandas as pd
import numpy as np
date=pd.date_range("2026-01-01",periods=30)
df=pd.DataFrame({"value":np.random.randint(1,100,size=30)},index=date)
print(f"original:\n{df}")
d=df.resample("ME").mean()
print(f"resamples month mean:\n{d}")
# Out:
# original:
#             value
# 2026-01-01     42
# 2026-01-02     14
# 2026-01-03     24
# 2026-01-04     36
# 2026-01-05     22
# 2026-01-06      4
# 2026-01-07     51
# 2026-01-08     91
# 2026-01-09     14
# 2026-01-10     26
# 2026-01-11     51
# 2026-01-12     94
# 2026-01-13     25
# 2026-01-14     24
# 2026-01-15     62
# 2026-01-16     82
# 2026-01-17     25
# 2026-01-18     36
# 2026-01-19     53
# 2026-01-20     55
# 2026-01-21     25
# 2026-01-22     67
# 2026-01-23     40
# 2026-01-24     59
# 2026-01-25     62
# 2026-01-26     30
# 2026-01-27     77
# 2026-01-28     95
# 2026-01-29     23
# 2026-01-30     77
# resamples month mean:
#             value
# 2026-01-31   46.2

# %%
import pandas as pd
import numpy as np
date=pd.date_range("2021-01-01",periods=30)
df=pd.DataFrame({"value":np.random.randint(1,100,size=30)},index=date)
print(f"original:\n{df}")
roll=df.rolling(window=7).mean()
print(f"rolling:\n{roll}")
# Out:
# original:
#             value
# 2021-01-01     49
# 2021-01-02     36
# 2021-01-03     95
# 2021-01-04     14
# 2021-01-05     12
# 2021-01-06     13
# 2021-01-07     75
# 2021-01-08     96
# 2021-01-09      7
# 2021-01-10     64
# 2021-01-11     55
# 2021-01-12     73
# 2021-01-13     32
# 2021-01-14      1
# 2021-01-15     67
# 2021-01-16     60
# 2021-01-17     92
# 2021-01-18     12
# 2021-01-19     10
# 2021-01-20     94
# 2021-01-21     22
# 2021-01-22     57
# 2021-01-23     60
# 2021-01-24      2
# 2021-01-25     35
# 2021-01-26      4
# 2021-01-27     91
# 2021-01-28     58
# 2021-01-29     34
# 2021-01-30     91
# rolling:
#                 value
# 2021-01-01        NaN
# 2021-01-02        NaN
# 2021-01-03        NaN
# 2021-01-04        NaN
# 2021-01-05        NaN
# 2021-01-06        NaN
# 2021-01-07  42.000000
# 2021-01-08  48.714286
# 2021-01-09  44.571429
# 2021-01-10  40.142857
# 2021-01-11  46.000000
# 2021-01-12  54.714286
# 2021-01-13  57.428571
# ...

# %%
# assignment 8
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Date":pd.date_range("2026-01-01",periods=6),
    "Category":np.random.choice(['A','B','C'],6),
    "Value":np.random.randint(10,100,6)
})

print(df)

pivot=df.pivot_table(values="Value",index="Date",columns="Category",aggfunc="sum")

print(pivot)
# Out:
#         Date Category  Value
# 0 2026-01-01        A     98
# 1 2026-01-02        B     12
# 2 2026-01-03        C     51
# 3 2026-01-04        C     93
# 4 2026-01-05        B     36
# 5 2026-01-06        C     30
# Category       A     B     C
# Date
# 2026-01-01  98.0   NaN   NaN
# 2026-01-02   NaN  12.0   NaN
# 2026-01-03   NaN   NaN  51.0
# 2026-01-04   NaN   NaN  93.0
# 2026-01-05   NaN  36.0   NaN
# 2026-01-06   NaN   NaN  30.0

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    "Year":np.random.choice([2022,2023,2024],6),
    "Quater":np.random.choice(['Q1','Q2','Q3'],6),
    "revenue":np.random.randint(10000,50000,6)
})

print(df)

pivot=df.pivot_table(values="revenue",index="Year",columns="Quater",aggfunc="mean")

print(pivot)
# Out:
#    Year Quater  revenue
# 0  2023     Q2    43743
# 1  2023     Q2    12709
# 2  2023     Q3    15757
# 3  2023     Q2    15615
# 4  2022     Q1    48702
# 5  2023     Q1    26498
# Quater       Q1            Q2       Q3
# Year
# 2022    48702.0           NaN      NaN
# 2023    26498.0  24022.333333  15757.0
